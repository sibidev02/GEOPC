# %%
import open3d as o3d
import numpy as np
import os

def calculate_m3c2_distances(cloud1: o3d.geometry.PointCloud, cloud2: o3d.geometry.PointCloud) -> np.ndarray:
    """
    Calculate distances between corresponding points in two point clouds (M3C2-like approach).
    """
    # Use KDTree for nearest neighbor search to find corresponding points
    cloud2_tree = o3d.geometry.KDTreeFlann(cloud2)

    distances = []
    for point in cloud1.points:
        [_, idx, _] = cloud2_tree.search_knn_vector_3d(point, 1)
        if len(idx) == 0:
            distances.append(np.inf)  # Assign infinity if no neighbor is found
        else:
            nearest_point = np.asarray(cloud2.points)[idx[0]]
            distance = np.linalg.norm(np.asarray(point) - nearest_point)
            distances.append(distance)

    return np.array(distances)

# Define paths
source_dir = r"C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\las_data\786901_2a_20180718_Mikro-Detail 100 clusters\786901_2a_20180718_Mikro-Detail\100"
target_dir = r"C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\las_data\786901_2a_20201118_Mikro-Detail 100 clusters\786901_2a_20201118_Mikro-Detail\100"
output_dir = r"C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4"

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Initialize total points filtered counter
total_filtered_points = 0

# Loop through source clusters (from 1 to 99) and target clusters (from 0 to 98)
for i in range(1, 100):  # source clusters start from 1, so loop from 1 to 99
    source_file = f"cluster_{i}.ply"  # source files start from cluster_1.ply
    target_file = f"cluster_{i-1}.ply"  # target files start from cluster_0.ply

    source_path = os.path.join(source_dir, source_file)
    target_path = os.path.join(target_dir, target_file)

    print(f"Processing source cluster {i} with target cluster {i-1}...")

    if os.path.exists(source_path) and os.path.exists(target_path):
        # Load the point clouds
        source_cloud = o3d.io.read_point_cloud(source_path)
        target_cloud = o3d.io.read_point_cloud(target_path)

        if len(source_cloud.points) == 0 or len(target_cloud.points) == 0:
            print(f"Empty point cloud for cluster {i}. Skipping.")
            continue

        # Calculate distances between corresponding points
        distances = calculate_m3c2_distances(source_cloud, target_cloud)

        # Define the threshold value
        threshold = 0.03

        # Find indices of points with distances greater than the threshold
        indices_above_threshold = np.where(distances > threshold)[0]

        # Create a new point cloud with only the points above the threshold
        filtered_points = np.asarray(source_cloud.points)[indices_above_threshold]
        filtered_colors = np.asarray(source_cloud.colors)[indices_above_threshold] if source_cloud.colors else None

        filtered_point_cloud = o3d.geometry.PointCloud()
        filtered_point_cloud.points = o3d.utility.Vector3dVector(filtered_points)
        if filtered_colors is not None:
            filtered_point_cloud.colors = o3d.utility.Vector3dVector(filtered_colors)

        # Save the filtered point cloud
        filtered_point_cloud_file_path = os.path.join(output_dir, f"filtered_cluster_{i}.ply")
        o3d.io.write_point_cloud(filtered_point_cloud_file_path, filtered_point_cloud)

        # Update total points filtered
        total_filtered_points += len(filtered_points)

        # Print the number of points filtered
        print(f"Cluster {i}: {len(filtered_points)} points filtered. Saved to {filtered_point_cloud_file_path}")

    else:
        print(f"Missing source or target point cloud for cluster {i}")

# Print the total number of points filtered
print(f"Total number of points filtered across all clusters: {total_filtered_points}")
print("Processing complete.")
# Out:
# Processing source cluster 1 with target cluster 0...
# Cluster 1: 716233 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_1.ply
# Processing source cluster 2 with target cluster 1...
# Cluster 2: 806333 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_2.ply
# Processing source cluster 3 with target cluster 2...
# Cluster 3: 188816 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_3.ply
# Processing source cluster 4 with target cluster 3...
# Cluster 4: 44882 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_4.ply
# Processing source cluster 5 with target cluster 4...
# Cluster 5: 114911 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_5.ply
# Processing source cluster 6 with target cluster 5...
# Cluster 6: 220199 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_6.ply
# Processing source cluster 7 with target cluster 6...
# Cluster 7: 839218 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_7.ply
# Processing source cluster 8 with target cluster 7...
# Cluster 8: 559227 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_8.ply
# Processing source cluster 9 with target cluster 8...
# Cluster 9: 7432 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_9.ply
# Processing source cluster 10 with target cluster 9...
# Missing source or target point cloud for cluster 10
# Processing source cluster 11 with target cluster 10...
# Cluster 11: 362 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_11.ply
# Processing source cluster 12 with target cluster 11...
# Cluster 12: 516376 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_12.ply
# Processing source cluster 13 with target cluster 12...
# Cluster 13: 564368 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_13.ply
# Processing source cluster 14 with target cluster 13...
# Cluster 14: 850259 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_14.ply
# Processing source cluster 15 with target cluster 14...
# Missing source or target point cloud for cluster 15
# Processing source cluster 16 with target cluster 15...
# Cluster 16: 340318 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_16.ply
# Processing source cluster 17 with target cluster 16...
# Cluster 17: 740298 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_17.ply
# Processing source cluster 18 with target cluster 17...
# Cluster 18: 154105 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_18.ply
# Processing source cluster 19 with target cluster 18...
# Cluster 19: 804573 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_19.ply
# Processing source cluster 20 with target cluster 19...
# Cluster 20: 494235 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_20.ply
# Processing source cluster 21 with target cluster 20...
# Missing source or target point cloud for cluster 21
# Processing source cluster 22 with target cluster 21...
# Cluster 22: 544199 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_22.ply
# Processing source cluster 23 with target cluster 22...
# Missing source or target point cloud for cluster 23
# Processing source cluster 24 with target cluster 23...
# Missing source or target point cloud for cluster 24
# Processing source cluster 25 with target cluster 24...
# Cluster 25: 691536 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_25.ply
# Processing source cluster 26 with target cluster 25...
# Cluster 26: 28693 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_26.ply
# Processing source cluster 27 with target cluster 26...
# Cluster 27: 674112 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_27.ply
# Processing source cluster 28 with target cluster 27...
# Cluster 28: 747527 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_28.ply
# Processing source cluster 29 with target cluster 28...
# Missing source or target point cloud for cluster 29
# Processing source cluster 30 with target cluster 29...
# Cluster 30: 747550 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_30.ply
# Processing source cluster 31 with target cluster 30...
# Cluster 31: 118458 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_31.ply
# Processing source cluster 32 with target cluster 31...
# Cluster 32: 70934 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_32.ply
# Processing source cluster 33 with target cluster 32...
# Cluster 33: 900800 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_33.ply
# Processing source cluster 34 with target cluster 33...
# Cluster 34: 658886 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_34.ply
# Processing source cluster 35 with target cluster 34...
# Missing source or target point cloud for cluster 35
# Processing source cluster 36 with target cluster 35...
# Cluster 36: 19486 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_36.ply
# Processing source cluster 37 with target cluster 36...
# Cluster 37: 80035 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_37.ply
# Processing source cluster 38 with target cluster 37...
# Cluster 38: 251921 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_38.ply
# Processing source cluster 39 with target cluster 38...
# Cluster 39: 774819 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_39.ply
# Processing source cluster 40 with target cluster 39...
# Cluster 40: 37 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_40.ply
# Processing source cluster 41 with target cluster 40...
# Cluster 41: 133175 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_41.ply
# Processing source cluster 42 with target cluster 41...
# Cluster 42: 661491 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_42.ply
# Processing source cluster 43 with target cluster 42...
# Cluster 43: 440574 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_43.ply
# Processing source cluster 44 with target cluster 43...
# Cluster 44: 272358 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_44.ply
# Processing source cluster 45 with target cluster 44...
# Cluster 45: 27566 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_45.ply
# Processing source cluster 46 with target cluster 45...
# Cluster 46: 611942 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_46.ply
# Processing source cluster 47 with target cluster 46...
# Cluster 47: 797590 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_47.ply
# Processing source cluster 48 with target cluster 47...
# Cluster 48: 683675 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_48.ply
# Processing source cluster 49 with target cluster 48...
# Cluster 49: 113178 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_49.ply
# Processing source cluster 50 with target cluster 49...
# Missing source or target point cloud for cluster 50
# Processing source cluster 51 with target cluster 50...
# Cluster 51: 5783 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_51.ply
# Processing source cluster 52 with target cluster 51...
# Cluster 52: 12511 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_52.ply
# Processing source cluster 53 with target cluster 52...
# Cluster 53: 622797 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_53.ply
# Processing source cluster 54 with target cluster 53...
# Cluster 54: 569444 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_54.ply
# Processing source cluster 55 with target cluster 54...
# Cluster 55: 745306 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_55.ply
# Processing source cluster 56 with target cluster 55...
# Missing source or target point cloud for cluster 56
# Processing source cluster 57 with target cluster 56...
# Cluster 57: 3261 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_57.ply
# Processing source cluster 58 with target cluster 57...
# Cluster 58: 390545 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_58.ply
# Processing source cluster 59 with target cluster 58...
# Cluster 59: 603233 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_59.ply
# Processing source cluster 60 with target cluster 59...
# Cluster 60: 615110 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_60.ply
# Processing source cluster 61 with target cluster 60...
# Missing source or target point cloud for cluster 61
# Processing source cluster 62 with target cluster 61...
# Cluster 62: 75563 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_62.ply
# Processing source cluster 63 with target cluster 62...
# Cluster 63: 636324 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_63.ply
# Processing source cluster 64 with target cluster 63...
# Cluster 64: 924472 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_64.ply
# Processing source cluster 65 with target cluster 64...
# Cluster 65: 67597 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_65.ply
# Processing source cluster 66 with target cluster 65...
# Cluster 66: 538404 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_66.ply
# Processing source cluster 67 with target cluster 66...
# Cluster 67: 435288 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_67.ply
# Processing source cluster 68 with target cluster 67...
# Cluster 68: 126352 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_68.ply
# Processing source cluster 69 with target cluster 68...
# Cluster 69: 409438 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_69.ply
# Processing source cluster 70 with target cluster 69...
# Cluster 70: 46 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_70.ply
# Processing source cluster 71 with target cluster 70...
# Cluster 71: 395052 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_71.ply
# Processing source cluster 72 with target cluster 71...
# Cluster 72: 686409 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_72.ply
# Processing source cluster 73 with target cluster 72...
# Cluster 73: 277632 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_73.ply
# Processing source cluster 74 with target cluster 73...
# Cluster 74: 59827 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_74.ply
# Processing source cluster 75 with target cluster 74...
# Cluster 75: 684389 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_75.ply
# Processing source cluster 76 with target cluster 75...
# Cluster 76: 260898 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_76.ply
# Processing source cluster 77 with target cluster 76...
# Cluster 77: 845310 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_77.ply
# Processing source cluster 78 with target cluster 77...
# Cluster 78: 341839 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_78.ply
# Processing source cluster 79 with target cluster 78...
# Missing source or target point cloud for cluster 79
# Processing source cluster 80 with target cluster 79...
# Missing source or target point cloud for cluster 80
# Processing source cluster 81 with target cluster 80...
# Missing source or target point cloud for cluster 81
# Processing source cluster 82 with target cluster 81...
# Cluster 82: 549055 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_82.ply
# Processing source cluster 83 with target cluster 82...
# Cluster 83: 206007 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_83.ply
# Processing source cluster 84 with target cluster 83...
# Cluster 84: 355307 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_84.ply
# Processing source cluster 85 with target cluster 84...
# Cluster 85: 722209 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_85.ply
# Processing source cluster 86 with target cluster 85...
# Cluster 86: 712581 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_86.ply
# Processing source cluster 87 with target cluster 86...
# Missing source or target point cloud for cluster 87
# Processing source cluster 88 with target cluster 87...
# Cluster 88: 68468 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_88.ply
# Processing source cluster 89 with target cluster 88...
# Missing source or target point cloud for cluster 89
# Processing source cluster 90 with target cluster 89...
# Cluster 90: 826380 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_90.ply
# Processing source cluster 91 with target cluster 90...
# Cluster 91: 60551 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_91.ply
# Processing source cluster 92 with target cluster 91...
# Cluster 92: 542938 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_92.ply
# Processing source cluster 93 with target cluster 92...
# Cluster 93: 15960 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_93.ply
# Processing source cluster 94 with target cluster 93...
# Cluster 94: 33952 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_94.ply
# Processing source cluster 95 with target cluster 94...
# Cluster 95: 522453 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_95.ply
# Processing source cluster 96 with target cluster 95...
# Cluster 96: 671822 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_96.ply
# Processing source cluster 97 with target cluster 96...
# Cluster 97: 627885 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_97.ply
# Processing source cluster 98 with target cluster 97...
# Cluster 98: 885163 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_98.ply
# Processing source cluster 99 with target cluster 98...
# Cluster 99: 879525 points filtered. Saved to C:\Users\devsibi\PycharmProjects\pythonProject4\lidar\output files\streaming Result\4\filtered_cluster_99.ply
# Total number of points filtered across all clusters: 36025773
# Processing complete.
